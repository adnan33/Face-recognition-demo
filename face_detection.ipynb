# %%
import dlib
import glob,os,cv2
import matplotlib.pyplot as plt
import face_recognition
import timeit

# %%
detector = dlib.get_frontal_face_detector()

# %%
img_dir = "raw_imgs/1.jpeg"
img = cv2.imread(img_dir)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # convert to grayscale

# %%
rects = detector(gray, 3)
# Out:
# 6.38 s ± 17.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print(rects)
# Out:
# rectangles[[(206, 313) (445, 553)], [(469, 282) (549, 362)], [(830, 264) (926, 360)]]

# %%
img2 = dlib.load_rgb_image(img_dir)
dets = detector(img2, 1)
print(dets)
# Out:
# rectangles[[(200, 290) (468, 558)], [(464, 275) (554, 365)]]

# %%
face_locations = face_recognition.face_locations(img,number_of_times_to_upsample=0, model="cnn")

# %%
face_locations
# Out:
# [(268, 555, 347, 476), (288, 440, 524, 205), (249, 925, 344, 830)]

# %%
rec_face = img.copy()
for loc in face_locations:
    top,right,bottom,left = loc
    rec_face = cv2.rectangle(img, (left,top), (right,bottom), (255,0,0), 2)
plt.imshow(img)
